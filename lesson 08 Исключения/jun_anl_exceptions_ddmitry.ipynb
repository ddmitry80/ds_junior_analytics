# %% [markdown]
# # Исключения
# ## Домашняя работа

# %% [markdown]
# ### Вопросы по лекциям.

# %% [markdown]
# Как поймать вообще все ошибки, которые могут произойти?

# %% [markdown]
# **Ответ:**
# try
#     ...
# except:
#     ...

# %% [markdown]
# Сколько раз подряд можно указывать except?

# %% [markdown]
# **Ответ:**
# Столько сколько видов ошибки нам нужно поймать

# %% [markdown]
# Вы хотите с помощью print вывести название ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**

# %% [markdown]
# Вы хотите с помощью print вывести параметры ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**
# try
#     ...
# except SomeException as exc:
#     print(exc.args)

# %% [markdown]
# Что такое DeprecationWarning?

# %% [markdown]
# **Ответ:**
# Предупреждение что данный функционал объявлен устаревшим и в будущем будет удален

# %% [markdown]
# ### Разминочные задания.
# <br>
#
# Вам даны две функции. Поисследуйте, какие ошибки могут возникнуть при их реализации. Обработайте эти ошибки.

# %%
def div():
    for i in range(2):
        try:
            x = int(input("enter a number: "))
            y = int(input("enter another number: "))
            print(x, '/', y, '=', x/y)
        except (ZeroDivisionError, ValueError) as err:
            print(f'Ошибка: {err.args}')
            
div()
# Out:
# enter a number:  0.3
# Ошибка: ("invalid literal for int() with base 10: '0.3'",)
# enter a number:  1
# enter another number:  3
# 1 / 3 = 0.3333333333333333

# %%
def sumOfPairs(L1, L2):
    sum = 0
    sumOfPairs = []
    try:
        for i in range(len(L1)):
            sumOfPairs.append(L1[i]+L2[i])
    except IndexError as err:
        print(f'Ошибка IndexError, {err.args}')
    except TypeError as err:
        print(f'Ошибка TypeError, {err.args}')
    print("sumOfPairs = ", sumOfPairs)

l1 = [1, 2, 3, 5]
l2 = [2, 3, '4']
sumOfPairs(l1, l2)
# Out:
# Ошибка TypeError, ("unsupported operand type(s) for +: 'int' and 'str'",)
# sumOfPairs =  [3, 5]

# %% [markdown]
# ### Задание 1.
#
# Есть файл с протоколом регистраций пользователей на сайте (registrations.txt).<br>
# Каждая строка содержит информацию о имени, электронной почте и возрасте человека. <br><br>
#
#
# Надо проверить данные из файла, для каждой строки:
#  - присутсвуют все три поля
#  - поле имени содержит только буквы
#  - поле email содержит @ и .
#  - поле возраст является числом от 10 до 99<br>
#
# В результате проверки нужно сформировать два файла
#  - registrations_good.log для правильных данных, записывать строки как есть
# - registrations_bad.log для ошибочных, записывать строку и вид ошибки.<br>
#
# Для валидации строки данных написать метод, который может выкидывать исключения:
#  - НЕ присутсвуют все три поля: ValueError
#  - поле имени содержит НЕ только буквы: NotNameError (кастомное исключение)
#  - поле email НЕ содержит @ и .(точку): NotEmailError (кастомное исключение)
#  - поле возраст НЕ является числом от 10 до 99: ValueError
# Вызов метода обернуть в try-except.

# %%
### YOUR CODE HERE ###
class NotNameError(Exception):
    pass

class NotEmailError(Exception):
    pass

def string_validation(line):
    name, email, age = line.split(' ')
    if name == None or email == None or age == None:
        raise ValueError("Строка не делится на имя, почту, возраст")
    if name.isalpha() == False:
        raise NotNameError('Имя содержит неразрешенные символы')
    if email.find('@') == -1 or email.find('.') == -1:
        raise NotEmailError('Email неверен')
    if age.isdigit():
        if  10 > int(age) or int(age) > 99:
            raise ValueError('Возраст не подходит')
    else:
        raise ValueError('Возраст не число')
    return True
    

with open('registrations.txt', 'r', encoding="utf-8") as ff:
    f_good = open('registrations_good.log','w', 1)
    f_bad = open('registrations_bad.log', 'w', 1)
    for i, line in enumerate(ff):
        line = line[:-1]
        try:
            if string_validation(line):
                f_good.write(line)
                f_good.write('\n')
        except (ValueError, NotEmailError, NotNameError) as err:
            f_bad.write(f'В строке {i} с содержимым "{line[:-1]}" ошибка "{err}"\n')
            print(f'В строке {i} с содержимым "{line[:-1]}" ошибка "{err}"')
f_good.close()
f_bad.close()
# Out:
#  9" ошибка "Имя содержит неразрешенные символы"
# В строке 8194 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8200 с содержимым "Ярослав!!!!1 wwmnsfvj@ya.ru 2" ошибка "Имя содержит неразрешенные символы"
# В строке 8224 с содержимым "Мария zpcmjr@gmail.com " ошибка "Возраст не подходит"
# В строке 8230 с содержимым "Чехова42 eezcpy@mail.ru 9" ошибка "Имя содержит неразрешенные символы"
# В строке 8234 с содержимым "Михаил 28 ilehibygt@mail.r" ошибка "Email неверен"
# В строке 8236 с содержимым "Ярослав 63 eaxnuai@ya.r" ошибка "Email неверен"
# В строке 8240 с содержимым "Хенг666 onttosa@ya.ru 8" ошибка "Имя содержит неразрешенные символы"
# В строке 8245 с содержимым "Ярослав666 vv@ya.ru 7" ошибка "Имя содержит неразрешенные символы"
# В строке 8246 с содержимым "Дмитрий 34 jccinp@mail.r" ошибка "Email неверен"
# В строке 8248 с содержимым "Ольга666 ibfzjk@ya.ru 9" ошибка "Имя содержит неразрешенные символы"
# В строке 8250 с содержимым "Земфира zhrfgfpc 8" ошибка "Email неверен"
# В строке 8265 с содержимым "Нагиев gsf@gmail.com " ошибка "Возраст не подходит"
# В строке 8283 с содержимым "Степан666 tkzvgm@mail.ru 7" ошибка "Имя содержит неразрешенные символы"
# В строке 8306 с содержимым "Геннадий666 gev@ya.ru 8" ошибка "Имя содержит неразрешенные символы"
# В строке 8312 с содержимым "Земфира lletd@mail.ru " ошибка "Возраст не подходит"
# В строке 8324 с содержимым "Владимир666 qudalgiaqm@gmail.com 6" ошибка "Имя содержит неразрешенные символы"
# В строке 8326 с содержимым "Владимир!!!!1 qzgghw@gmail.com 1" ошибка "Имя содержит неразрешенные символы"
# В строке 8334 с содержимым "Сянцзян osopkc@gmail.com " ошибка "Возраст не подходит"
# В строке 8338 с содержимым "Мария mnfigvam 2" ошибка "Email неверен"
# В строке 8339 с содержимым "Артём pudlfmzpwi@mail.ru 10" ошибка "Возраст не подходит"
# В строке 8346 с содержимым "Земфира duyfg@gmail.com " ошибка "Возраст не подходит"
# В строке 8350 с содержимым "Муммий666 bh@gmail.com 3" ошибка "Имя содержит неразрешенные символы"
# В строке 8360 с содержимым "Волочкова hk@gmail.com " ошибка "Возраст не подходит"
# В строке 8382 с содержимым "Ольга sunia.mail.ru 6" ошибка "Email неверен"
# В строке 8385 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8386 с содержимым "Нагиев hekhxxlfigvam 6" ошибка "Email неверен"
# В строке 8390 с содержимым "7" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8404 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8407 с содержимым "Ван42 xm@gmail.com 3" ошибка "Имя содержит неразрешенные символы"
# В строке 8408 с содержимым "Геннадий ipddomkxs@ya.ru 10" ошибка "Возраст не подходит"
# В строке 8412 с содержимым "Ярослав mjp@ya.ru 10" ошибка "Возраст не подходит"
# В строке 8429 с содержимым "Степан ueubww@mail.ru " ошибка "Возраст не подходит"
# В строке 8443 с содержимым "Ли!!!!1 srjvpum@gmail.com 6" ошибка "Имя содержит неразрешенные символы"
# В строке 8452 с содержимым "Чехова 23 fogfgwr@ya.r" ошибка "Email неверен"
# В строке 8491 с содержимым "Дмитрий 33 bewlfhvxxv@ya.r" ошибка "Email неверен"
# В строке 8515 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8517 с содержимым "Бузова 85 ymtcb@mail.r" ошибка "Email неверен"
# В строке 8521 с содержимым "Равшан!!!!1 wxh@mail.ru 1" ошибка "Имя содержит неразрешенные символы"
# В строке 8523 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8524 с содержимым "Чонгкун 13 rqkwufl@ya.r" ошибка "Email неверен"
# В строке 8525 с содержимым "Нагиев666 jebsjraw@ya.ru 6" ошибка "Имя содержит неразрешенные символы"
# В строке 8531 с содержимым "Дмитрий xkveyjt.ru 9" ошибка "Email неверен"
# В строке 8533 с содержимым "Хенг!!!!1 kxp@gmail.com 6" ошибка "Имя содержит неразрешенные символы"
# В строке 8551 с содержимым "Нагиев666 ou@mail.ru 2" ошибка "Имя содержит неразрешенные символы"
# В строке 8554 с содержимым "Земфира abfigvam 9" ошибка "Email неверен"
# В строке 8557 с содержимым "Ярослав xx.mail.ru 4" ошибка "Email неверен"
# В строке 8565 с содержимым "Волочкова oefgutnvw@mail.ru 10" ошибка "Возраст не подходит"
# В строке 8576 с содержимым "Яочуан666 vtkmd@ya.ru 3" ошибка "Имя содержит неразрешенные символы"
# В строке 8578 с содержимым "Ольга42 dh@ya.ru 2" ошибка "Имя содержит неразрешенные символы"
# В строке 8585 с содержимым "Ли ugbeuptrtn@ya.ru " ошибка "Возраст не подходит"
# В строке 8591 с содержимым "Сянцзян!!!!1 eofcojuehm@ya.ru 3" ошибка "Имя содержит неразрешенные символы"
# В строке 8603 с содержимым "Равшан ab.ru 1" ошибка "Email неверен"
# В строке 8613 с содержимым "Яочуан!!!!1 hrkqrm@mail.ru 8" ошибка "Имя содержит неразрешенные символы"
# В строке 8625 с содержимым "Артём!!!!1 qafsowppis@gmail.com 4" ошибка "Имя содержит неразрешенные символы"
# В строке 8630 с содержимым "Джигурда htufigvam 1" ошибка "Email неверен"
# В строке 8635 с содержимым "Земфира klzjeoxnq@ya.ru 10" ошибка "Возраст не подходит"
# В строке 8655 с содержимым "Яочуан mmbbjfmwb@ya.ru " ошибка "Возраст не подходит"
# В строке 8664 с содержимым "Нагиев ap@mail.ru " ошибка "Возраст не подходит"
# В строке 8691 с содержимым "Ольга666 vr@mail.ru 10" ошибка "Имя содержит неразрешенные символы"
# В строке 8694 с содержимым "Сянцзян nrg@gmail.com " ошибка "Возраст не подходит"
# В строке 8698 с содержимым "6" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8706 с содержимым "Мария koieqn@mail.ru " ошибка "Возраст не подходит"
# В строке 8709 с содержимым "Чехова 8" ошибка "not enough values to unpack (expected 3, got 2)"
# В строке 8710 с содержимым "Дмитрий tdrc@gmail.com 10" ошибка "Возраст не подходит"
# В строке 8713 с содержимым "Равша" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8719 с содержимым "Равшан gwtfigvam 9" ошибка "Email неверен"
# В строке 8721 с содержимым "Мария666 fxkiz@mail.ru 6" ошибка "Имя содержит неразрешенные символы"
# В строке 8725 с содержимым "Ли ieutg.ru 7" ошибка "Email неверен"
# В строке 8729 с содержимым "Степан egevtifebg@gmail.com 10" ошибка "Возраст не подходит"
# В строке 8737 с содержимым "Равшан pvtwyqxc@gmail.com " ошибка "Возраст не подходит"
# В строке 8741 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8744 с содержимым "Земфира eqmwug@mail.ru 10" ошибка "Возраст не подходит"
# В строке 8749 с содержимым "Чонгкун gysadqnc@gmail.com " ошибка "Возраст не подходит"
# В строке 8751 с содержимым "pt@ya.r" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8753 с содержимым "Ли luzo@gmail.com " ошибка "Возраст не подходит"
# В строке 8754 с содержимым "Гнойный xyvjancymu@mail.ru " ошибка "Возраст не подходит"
# В строке 8764 с содержимым "Ван fierz@gmail.com " ошибка "Возраст не подходит"
# В строке 8781 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8785 с содержимым "Владимир666 hjwqgntzb@gmail.com 7" ошибка "Имя содержит неразрешенные символы"
# В строке 8787 с содержимым "Джамшут42 mutpfnzqy@mail.ru 6" ошибка "Имя содержит неразрешенные символы"
# В строке 8797 с содержимым "Ли zauapqu.ru 3" ошибка "Email неверен"
# В строке 8798 с содержимым "Хенг gn.mail.ru 7" ошибка "Email неверен"
# В строке 8804 с содержимым "Ольга nx 5" ошибка "Email неверен"
# В строке 8823 с содержимым "Ли mydowr@ya.ru 10" ошибка "Возраст не подходит"
# В строке 8827 с содержимым "Ли finxkaeqo@mail.ru " ошибка "Возраст не подходит"
# В строке 8850 с содержимым "Артём okodti@gmail.com " ошибка "Возраст не подходит"
# В строке 8867 с содержимым "Дмитрий hqgon@ya.ru " ошибка "Возраст не подходит"
# В строке 8868 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 8869 с содержимым "Равшан xjsibxpos@mail.ru " ошибка "Возраст не подходит"
# В строке 8875 с содержимым "Чехова 80 lsyfvzjhx@gmail.co" ошибка "Email неверен"
# В строке 8879 с содержимым "Чехова42 fqsgq@ya.ru 7" ошибка "Имя содержит неразрешенные символы"
# В строке 8886 с содержимым "Артём irrx " ошибка "Email неверен"
# В строке 8894 с содержимым "Степан hnkomvo@ya.ru " ошибка "Возраст не подходит"
# В строке 8905 с содержимым "Ли gggep@mail.ru " ошибка "Возраст не подходит"
# В строке 8912 с содержимым "Нагиев 39 xexcn@mail.r" ошибка "Email неверен"
# В строке 8915 с содержимым "Мария dpdkgrk@mail.ru " ошибка "Возраст не подходит"
# В строке 8930 с содержимым "Чехова slouvlfjhp.mail.ru 10" ошибка "Email неверен"
# В строке 8940 с содержимым "Ольга jgsvnytwj@gmail.com 10" ошибка "Возраст не подходит"
# В строке 8959 с содержимым "Волочкова ofkuhzxqa@mail.ru 10" ошибка "Возраст не подходит"
# В строке 8965 с содержимым "Земфира vegfigvam 7" ошибка "Email неверен"
# В строке 8977 с содержимым "Степан npghipo@ya.ru " ошибка "Возраст не подходит"
# В строке 8987 с содержимым "Анна verpjfigvam 9" ошибка "Email неверен"
# В строке 9008 с содержимым "Бузова hunjg 5" ошибка "Email неверен"
# В строке 9011 с содержимым "Ли wnqnnhqnu@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9013 с содержимым "Ли duejc@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9015 с содержимым "Гнойный jezdkxv.mail.ru 3" ошибка "Email неверен"
# В строке 9025 с содержимым "Хенг texclyvv@ya.ru " ошибка "Возраст не подходит"
# В строке 9029 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9031 с содержимым "Равшан dhoyzo.mail.ru 5" ошибка "Email неверен"
# В строке 9033 с содержимым "Равшан hhwldj@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9041 с содержимым "Нагиев 32 ddqkqncsc@mail.r" ошибка "Email неверен"
# В строке 9044 с содержимым "Геннадий gku@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9047 с содержимым "Ван vv.ru 2" ошибка "Email неверен"
# В строке 9053 с содержимым "Михаил mqfigvam 4" ошибка "Email неверен"
# В строке 9054 с содержимым "Геннадий ztwc@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9055 с содержимым "Сянцзя" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9065 с содержимым "Джигурда ddvn@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9078 с содержимым "40 vdetvumek@gmail.co" ошибка "not enough values to unpack (expected 3, got 2)"
# В строке 9084 с содержимым "Хенг wnnokxhfi@ya.ru " ошибка "Возраст не подходит"
# В строке 9097 с содержимым "Ярослав lbywftp@mail.ru " ошибка "Возраст не подходит"
# В строке 9103 с содержимым "Земфира vuzzvyh@gmail.com " ошибка "Возраст не подходит"
# В строке 9107 с содержимым "Ван lpu@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9108 с содержимым "Яочуан yuz@gmail.com " ошибка "Возраст не подходит"
# В строке 9116 с содержимым "Джамшут rfaxstwl@ya.ru " ошибка "Возраст не подходит"
# В строке 9122 с содержимым "Анна anfh 3" ошибка "Email неверен"
# В строке 9138 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9143 с содержимым "Владимир 79 jwnhvvd@mail.r" ошибка "Email неверен"
# В строке 9148 с содержимым "Ли omk@ya.ru " ошибка "Возраст не подходит"
# В строке 9151 с содержимым "Земфира42 xsxj@mail.ru 9" ошибка "Имя содержит неразрешенные символы"
# В строке 9163 с содержимым "Степан zhbrwwfigvam 9" ошибка "Email неверен"
# В строке 9169 с содержимым "Ли ati@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9170 с содержимым "Ли pinle@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9173 с содержимым "Бузова fgmdzbhhus.mail.ru 8" ошибка "Email неверен"
# В строке 9188 с содержимым "Владимир xvrxzprb.ru 6" ошибка "Email неверен"
# В строке 9191 с содержимым "Ли xltzkbtd 2" ошибка "Email неверен"
# В строке 9195 с содержимым "Степан faydat 3" ошибка "Email неверен"
# В строке 9199 с содержимым "Степан nlfigvam 1" ошибка "Email неверен"
# В строке 9203 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9204 с содержимым "Чехова zlwudasr@ya.ru " ошибка "Возраст не подходит"
# В строке 9205 с содержимым "Земфира666 otxxpaiu@ya.ru 6" ошибка "Имя содержит неразрешенные символы"
# В строке 9216 с содержимым "Бузова rdvhta.mail.ru 7" ошибка "Email неверен"
# В строке 9229 с содержимым "Сянцзян cvb 3" ошибка "Email неверен"
# В строке 9233 с содержимым "Артём ug 1" ошибка "Email неверен"
# В строке 9234 с содержимым "Джамшут lgwoaerkg@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9244 с содержимым "vcbqv@mail.r" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9249 с содержимым "Джамшут qnju 1" ошибка "Email неверен"
# В строке 9260 с содержимым "Волочкова vbw@ya.ru " ошибка "Возраст не подходит"
# В строке 9272 с содержимым "Чехова hymvrilgca.ru 2" ошибка "Email неверен"
# В строке 9273 с содержимым "Чехова xzxezuwdo@mail.ru " ошибка "Возраст не подходит"
# В строке 9276 с содержимым "Михаил kpwnmczyg@ya.ru " ошибка "Возраст не подходит"
# В строке 9295 с содержимым "Сянцзян ddsto@mail.ru " ошибка "Возраст не подходит"
# В строке 9298 с содержимым "Земфира jiul 2" ошибка "Email неверен"
# В строке 9302 с содержимым "Хенг wdigvfokm@mail.r" ошибка "not enough values to unpack (expected 3, got 2)"
# В строке 9312 с содержимым "Равшан hjleuh@gmail.com " ошибка "Возраст не подходит"
# В строке 9315 с содержимым "Тролль zlivjohx@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9327 с содержимым "Артём wsqxhe.mail.ru 5" ошибка "Email неверен"
# В строке 9330 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9344 с содержимым "Артём grhwwz@gmail.com " ошибка "Возраст не подходит"
# В строке 9348 с содержимым "Чонгкун hcfuvw 8" ошибка "Email неверен"
# В строке 9382 с содержимым "Ольга ia@gmail.com " ошибка "Возраст не подходит"
# В строке 9387 с содержимым "Степан ay@ya.ru " ошибка "Возраст не подходит"
# В строке 9402 с содержимым "Чонгкун wrmis@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9403 с содержимым "Геннадий 60 qe@mail.r" ошибка "Email неверен"
# В строке 9405 с содержимым "Ольг" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9407 с содержимым "Анна aqkdbkyeb@gmail.com " ошибка "Возраст не подходит"
# В строке 9420 с содержимым "Владимир wv.ru 6" ошибка "Email неверен"
# В строке 9424 с содержимым "Анна42 ed@mail.ru 1" ошибка "Имя содержит неразрешенные символы"
# В строке 9425 с содержимым "Бузова xoyg@mail.ru " ошибка "Возраст не подходит"
# В строке 9453 с содержимым "Джамшут depp@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9455 с содержимым "Муммий!!!!1 scqo@mail.ru 9" ошибка "Имя содержит неразрешенные символы"
# В строке 9460 с содержимым "Владимир grrnerwhl@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9469 с содержимым "Ли vjarik@ya.ru " ошибка "Возраст не подходит"
# В строке 9473 с содержимым "Джамшут 3" ошибка "not enough values to unpack (expected 3, got 2)"
# В строке 9476 с содержимым "Яочуан kcbataacan@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9484 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9486 с содержимым "Тролль vfgb.mail.ru 6" ошибка "Email неверен"
# В строке 9498 с содержимым "Сянцзян ep.mail.ru 5" ошибка "Email неверен"
# В строке 9518 с содержимым "Хенг qgonstc@mail.ru " ошибка "Возраст не подходит"
# В строке 9524 с содержимым "Джигурда!!!!1 xpomzztfou@mail.ru 6" ошибка "Имя содержит неразрешенные символы"
# В строке 9536 с содержимым "Анна qcsrfjho@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9537 с содержимым "Анна whlbfloq.mail.ru 9" ошибка "Email неверен"
# В строке 9541 с содержимым "" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9551 с содержимым "Михаил666 kssuv@gmail.com 9" ошибка "Имя содержит неразрешенные символы"
# В строке 9554 с содержимым "Ли ivmjtzik@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9555 с содержимым "Волочкова lulntpfigvam 2" ошибка "Email неверен"
# В строке 9570 с содержимым "Чонгкун ogoujvw@mail.ru " ошибка "Возраст не подходит"
# В строке 9577 с содержимым "Волочкова666 qpaiijbtfigvam 5" ошибка "Имя содержит неразрешенные символы"
# В строке 9583 с содержимым "Чехова twfaumdygs 3" ошибка "Email неверен"
# В строке 9588 с содержимым "Ван42 vpvya@ya.ru 1" ошибка "Имя содержит неразрешенные символы"
# В строке 9592 с содержимым "Дмитрий py@gmail.co" ошибка "not enough values to unpack (expected 3, got 2)"
# В строке 9604 с содержимым "Пенг qwenv@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9605 с содержимым "Анна666 zvuc@gmail.com 2" ошибка "Имя содержит неразрешенные символы"
# В строке 9609 с содержимым "Геннадий 10 sdnri@mail.r" ошибка "Email неверен"
# В строке 9610 с содержимым "Гнойный fj@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9617 с содержимым "Муммий vksqce@mail.ru " ошибка "Возраст не подходит"
# В строке 9622 с содержимым "Чехова jewi@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9625 с содержимым "Волочкова ojzvn@mail.ru " ошибка "Возраст не подходит"
# В строке 9642 с содержимым "Геннадий 7" ошибка "not enough values to unpack (expected 3, got 2)"
# В строке 9657 с содержимым "Сянцзян 97 xangyo@ya.r" ошибка "Email неверен"
# В строке 9659 с содержимым "Гнойный jproimqazq@gmail.com " ошибка "Возраст не подходит"
# В строке 9665 с содержимым "Анна hwqdzkt 8" ошибка "Email неверен"
# В строке 9680 с содержимым "Пенг ft@mail.r" ошибка "not enough values to unpack (expected 3, got 2)"
# В строке 9682 с содержимым "Ли rpsbjxcidy@ya.ru " ошибка "Возраст не подходит"
# В строке 9687 с содержимым "Геннадий jrfxflls@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9694 с содержимым "Чонгкун 51 gaugtep@mail.r" ошибка "Email неверен"
# В строке 9709 с содержимым "Геннадий xdrmu@mail.ru " ошибка "Возраст не подходит"
# В строке 9713 с содержимым "Джамшут 6" ошибка "not enough values to unpack (expected 3, got 2)"
# В строке 9719 с содержимым "Дмитрий imkjxt@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9735 с содержимым "Хенг flsiogmwfv.mail.ru 6" ошибка "Email неверен"
# В строке 9737 с содержимым "Степан cwpxzmvcys@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9741 с содержимым "Волочкова ccni@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9747 с содержимым "Джамшу" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9761 с содержимым "Хенг rlbvvaq 2" ошибка "Email неверен"
# В строке 9780 с содержимым "Анна qi@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9797 с содержимым "Джамшут bumqppdlj@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9813 с содержимым "Тролль sw 5" ошибка "Email неверен"
# В строке 9833 с содержимым "Джамшут qtm@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9850 с содержимым "Джигурда42 byuxfoyigk@ya.ru 2" ошибка "Имя содержит неразрешенные символы"
# В строке 9879 с содержимым "Ли ykpenvzfigvam 3" ошибка "Email неверен"
# В строке 9884 с содержимым "9" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9896 с содержимым "Земфира azxq 8" ошибка "Email неверен"
# В строке 9904 с содержимым "Ли yaagqzrje@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9905 с содержимым "Артём by@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9911 с содержимым "Яочуан bpn@ya.ru " ошибка "Возраст не подходит"
# В строке 9915 с содержимым "Чонгкун sayoo@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9922 с содержимым "Яочуан42 zihdblwz@mail.ru 9" ошибка "Имя содержит неразрешенные символы"
# В строке 9924 с содержимым "Ольга hrvxhaieg@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9929 с содержимым "Чехова ieiq@gmail.com 10" ошибка "Возраст не подходит"
# В строке 9933 с содержимым "Владимир edx@ya.ru 10" ошибка "Возраст не подходит"
# В строке 9934 с содержимым "Равшан mdza.ru 9" ошибка "Email неверен"
# В строке 9936 с содержимым "6" ошибка "not enough values to unpack (expected 3, got 1)"
# В строке 9938 с содержимым "Джамшут666 kjw@gmail.com 2" ошибка "Имя содержит неразрешенные символы"
# В строке 9952 с содержимым "Бузова uri@mail.ru " ошибка "Возраст не подходит"
# В строке 9960 с содержимым "Гнойный dbvk@mail.ru 10" ошибка "Возраст не подходит"
# В строке 9964 с содержимым "Ван rgjaqkqs@gmail.com " ошибка "Возраст не подходит"
# В строке 9973 с содержимым "Волочкова mnu@mail.ru " ошибка "Возраст не подходит"
# В строке 9989 с содержимым "Ли42 vqffrrlfh@gmail.com 9" ошибка "Имя содержит неразрешенные символы"
# В строке 9990 с содержимым "Тролль666 se@mail.ru 5" ошибка "Имя содержит неразрешенные символы"
# В строке 9997 с содержимым "Дмитрий xayinimkz@mail.ru " ошибка "Возраст не подходит"
